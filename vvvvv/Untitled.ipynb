# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
sns.pairplot(df)

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
y=df.drop(["PassengerId"],axis=1)
y
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  \
# 0           0       3  22.0      1      0   7.2500
# 1           1       1  38.0      1      0  71.2833
# 2           1       3  26.0      0      0   7.9250
# 3           1       1  35.0      1      0  53.1000
# 4           0       3  35.0      0      0   8.0500
# ..        ...     ...   ...    ...    ...      ...
# 886         0       2  27.0      0      0  13.0000
# 887         1       1  19.0      0      0  30.0000
# 888         0       3   NaN      1      2  23.4500
# 889         1       1  26.0      0      0  30.0000
# 890         0       3  32.0      0      0   7.7500
#
#      Name_Abbott, Mr. Rossmore Edward  Name_Abbott, Mrs. Stanton (Rosa Hunt)  \
# 0                               False                                  False
# 1                               False                                  False
# 2                               False                                  False
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Name_Abbott, Mr. Rossmore Edward',
#        'Name_Abbott, Mrs. Stanton (Rosa Hunt)', 'Name_Abelson, Mr. Samuel',
#        ...
#        'Cabin_F G63', 'Cabin_F G73', 'Cabin_F2', 'Cabin_F33', 'Cabin_F38',
#        'Cabin_F4', 'Cabin_G6', 'Cabin_T', 'Embarked_Q', 'Embarked_S'],
#       dtype='object', length=1726)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  \
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500
#
#    Name_Abbott, Mr. Rossmore Edward  Name_Abbott, Mrs. Stanton (Rosa Hunt)  \
# 0                             False                                  False
# 1                             False                                  False
# 2                             False                                  False
# 3                             False                                  False
# 4                             False                                  False
#
#    Name_Abelson, Mr. Samuel  ...  Cabin_F G63  Cabin_F G73  Cabin_F2  \
# ...

# %%
x=df.iloc[:,1
# Out:
#      PassengerId  Pclass     Sex   Age  SibSp  Parch            Ticket  \
# 0              1       3    male  22.0      1      0         A/5 21171
# 1              2       1  female  38.0      1      0          PC 17599
# 2              3       3  female  26.0      0      0  STON/O2. 3101282
# 3              4       1  female  35.0      1      0            113803
# 4              5       3    male  35.0      0      0            373450
# ..           ...     ...     ...   ...    ...    ...               ...
# 886          887       2    male  27.0      0      0            211536
# 887          888       1  female  19.0      0      0            112053
# 888          889       3  female   NaN      1      2        W./C. 6607
# 889          890       1    male  26.0      0      0            111369
# 890          891       3    male  32.0      0      0            370376
#
#         Fare Cabin Embarked
# 0     7.2500   NaN        S
# 1    71.2833   C85        C
# ...

# %%
sns.pairplot(df)

# %%
sns.barplot(df['Sex'],['Passenger'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 sns.barplot(df['Sex'],['Passenger'])
#
# TypeError: barplot() takes from 0 to 1 positional arguments but 2 were given

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Pclass       891 non-null    int64
#  2   Sex          891 non-null    object
#  3   Age          714 non-null    float64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
#  6   Ticket       891 non-null    object
#  7   Fare         891 non-null    float64
#  8   Cabin        204 non-null    object
#  9   Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 69.7+ KB

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
lim=df["Fare"].quantile(0.75)-df["Fare"].quantile(0.25)
ul=df["Fare"].quantile(0.75)+1.5*lim
ll=df["Fare"].quantile(0.25)-1.5*lim

# %%
for i in not index:
    df['Fare' ]

# %%
pd.get_dummies(df,drop_first=True)
# Out:
#      PassengerId  Pclass  SibSp  Parch     Fare  Sex_male  Age_38.0  Age_26.0  \
# 0              1       3      1      0   7.2500      True     False     False
# 1              2       1      1      0  71.2833     False      True     False
# 2              3       3      0      0   7.9250     False     False      True
# 3              4       1      1      0  53.1000     False     False     False
# 4              5       3      0      0   8.0500      True     False     False
# ..           ...     ...    ...    ...      ...       ...       ...       ...
# 886          887       2      0      0  13.0000      True     False     False
# 887          888       1      0      0  30.0000     False     False     False
# 888          889       3      1      2  23.4500     False     False     False
# 889          890       1      0      0  30.0000      True     False      True
# 890          891       3      0      0   7.7500      True     False     False
#
#      Age_35.0  \
# 0       False
# ...

# %%
x=df.iloc[:,0:8].values
x
# Out:
# array([[1, 3, 'male', ..., 0, 'A/5 21171', 7.25],
#        [2, 1, 'female', ..., 0, 'PC 17599', 71.2833],
#        [3, 3, 'female', ..., 0, 'STON/O2. 3101282', 7.925],
#        ...,
#        [889, 3, 'female', ..., 2, 'W./C. 6607', 23.45],
#        [890, 1, 'male', ..., 0, '111369', 30.0],
#        [891, 3, 'male', ..., 0, '370376', 7.75]],
#       shape=(891, 8), dtype=object)

# %%
y=df.iloc[:,-1].values
y
# Out:
# array(['S', 'C', 'S', 'S', 'S', 'Q', 'S', 'S', 'S', 'C', 'S', 'S', 'S',
#        'S', 'S', 'S', 'Q', 'S', 'S', 'C', 'S', 'S', 'Q', 'S', 'S', 'S',
#        'C', 'S', 'Q', 'S', 'C', 'C', 'Q', 'S', 'C', 'S', 'C', 'S', 'S',
#        'C', 'S', 'S', 'C', 'C', 'Q', 'S', 'Q', 'Q', 'C', 'S', 'S', 'S',
#        'C', 'S', 'C', 'S', 'S', 'C', 'S', 'S', 'C', nan, 'S', 'S', 'C',
#        'C', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'C', 'S', 'S', 'S', 'S',
#        'S', 'S', 'S', 'S', 'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S',
#        'S', 'S', 'S', 'S', 'S', 'C', 'C', 'S', 'S', 'S', 'S', 'S', 'S',
#        'S', 'S', 'S', 'S', 'S', 'Q', 'S', 'C', 'S', 'S', 'C', 'S', 'Q',
#        'S', 'C', 'S', 'S', 'S', 'C', 'S', 'S', 'C', 'Q', 'S', 'C', 'S',
#        'C', 'S', 'S', 'S', 'S', 'C', 'S', 'S', 'S', 'C', 'C', 'S', 'S',
#        'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'C',
#        'Q', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S', 'S',
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=20,random_state=0)

# %%
x_train.shape
# Out:
# (871, 8)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
y_test
# Out:
# array(['C', 'S', 'Q', 'C', 'C', 'S', 'S', 'S', 'C', 'C', 'S', 'S', 'Q',
#        'S', 'C', 'S', 'S', 'S', 'S', 'C'], dtype=object)

# %%
from sklearn import metrics

# %%
metrics.confusion_matrix(y_test,pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 metrics.confusion_matrix(y_test,pred)
#
# NameError: name 'pred' is not defined

# %%
metricsaccuracy_score(y_test,pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 metricsaccuracy_score(y_test,pred)
#
# NameError: name 'metricsaccuracy_score' is not defined

# %%
metrics.confusion_matrix(y_test,pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 metrics.confusion_matrix(y_test,pred)
#
# NameError: name 'pred' is not defined

# %%
from sklearn.preprocessing import StandardScaler
x=StandardScaler()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()
